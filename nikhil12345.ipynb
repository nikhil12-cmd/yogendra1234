# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("building-points.csv",delimiter=';', skiprows=0, low_memory=False)
df.head()
# Out:
#             pin                                owner                  owner2  \
# 0  7.641434e+10                       GINKGO BVG LLC                     NaN
# 1  7.641443e+10                CIMATO, BRETT TRUSTEE  JONES, SHANNON TRUSTEE
# 2  7.641972e+10      JORDAN REAL ESTATE HOLDINGS LLC                     NaN
# 3  7.641721e+10  WALKER & WEST FAMILY PROPERTIES LLC                     NaN
# 4  7.641721e+10  WALKER & WEST FAMILY PROPERTIES LLC                     NaN
#
#                 owneradd1                    owneradd2           owneradd3  \
# 0  GINKGO RESIDENTIAL LLC  1023 W MOREHEAD STE STE 301  CHARLOTTE NC 28208
# 1      600 N HARRISON AVE           CARY NC 27513-4607                 NaN
# 2             PO BOX 4422           CARY NC 27519-4422                 NaN
# 3       930 SE MAYNARD RD           CARY NC 27511-4208                 NaN
# 4       930 SE MAYNARD RD           CARY NC 27511-4208                 NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189039 entries, 0 to 189038
# Data columns (total 37 columns):
# pin                  189039 non-null float64
# owner                189039 non-null object
# owner2               35466 non-null object
# owneradd1            189039 non-null object
# owneradd2            189018 non-null object
# owneradd3            6314 non-null object
# location             189039 non-null object
# building_type        189038 non-null object
# building_sub_type    184900 non-null object
# bldgstyle            175134 non-null object
# yearbuilt            177467 non-null float64
# units                189039 non-null float64
# sqft                 189039 non-null float64
# rooms                189039 non-null float64
# storyheight          163074 non-null object
# rooftype             0 non-null float64
# roof_floorsys        13796 non-null object
# extwall              176720 non-null object
# basement             148221 non-null object
# ...

# %%
df=df.drop(["pin","owner2"],axis=1)
df.head()
# Out:
#                                  owner               owneradd1  \
# 0                       GINKGO BVG LLC  GINKGO RESIDENTIAL LLC
# 1                CIMATO, BRETT TRUSTEE      600 N HARRISON AVE
# 2      JORDAN REAL ESTATE HOLDINGS LLC             PO BOX 4422
# 3  WALKER & WEST FAMILY PROPERTIES LLC       930 SE MAYNARD RD
# 4  WALKER & WEST FAMILY PROPERTIES LLC       930 SE MAYNARD RD
#
#                      owneradd2           owneradd3                location  \
# 0  1023 W MOREHEAD STE STE 301  CHARLOTTE NC 28208  200 ELDERBERRY HILL CT
# 1           CARY NC 27513-4607                 NaN      600 N HARRISON AVE
# 2           CARY NC 27519-4422                 NaN        407 E CHATHAM ST
# 3           CARY NC 27511-4208                 NaN        411 W CHATHAM ST
# 4           CARY NC 27511-4208                 NaN        413 W CHATHAM ST
#
#   building_type  building_sub_type     bldgstyle  yearbuilt  units  ...  \
# ...

# %%
df=df.drop(["owneradd3","streetmisc","streetsuffix","geo_shape","geo_point_2d"],axis=1)
df.head()
# Out:
#                                  owner               owneradd1  \
# 0                       GINKGO BVG LLC  GINKGO RESIDENTIAL LLC
# 1                CIMATO, BRETT TRUSTEE      600 N HARRISON AVE
# 2      JORDAN REAL ESTATE HOLDINGS LLC             PO BOX 4422
# 3  WALKER & WEST FAMILY PROPERTIES LLC       930 SE MAYNARD RD
# 4  WALKER & WEST FAMILY PROPERTIES LLC       930 SE MAYNARD RD
#
#                      owneradd2                location building_type  \
# 0  1023 W MOREHEAD STE STE 301  200 ELDERBERRY HILL CT     Apartment
# 1           CARY NC 27513-4607      600 N HARRISON AVE   Residential
# 2           CARY NC 27519-4422        407 E CHATHAM ST        Retail
# 3           CARY NC 27511-4208        411 W CHATHAM ST    Industrial
# 4           CARY NC 27511-4208        413 W CHATHAM ST    Industrial
#
#    building_sub_type     bldgstyle  yearbuilt  units     sqft  ...  realid  \
# 0          Townhouse     Townhouse     1999.0    6.0   7280.0  ...   37845
# ...

# %%
df=df.drop(["streetprefix","owneradd2","location","building_sub_type","rooftype","roof_floorsys","building_type","extwall","utilities","streettype","owneradd1","bathrooms","bldgstyle","basement","remodelyr","streetnumber","streetname","phycity","phyzip","storyheight"],axis=1)
df.head()
# Out:
#                                  owner  yearbuilt  units     sqft  rooms  \
# 0                       GINKGO BVG LLC     1999.0    6.0   7280.0    0.0
# 1                CIMATO, BRETT TRUSTEE     1960.0    2.0   2982.0    0.0
# 2      JORDAN REAL ESTATE HOLDINGS LLC     1961.0    0.0   3224.0    0.0
# 3  WALKER & WEST FAMILY PROPERTIES LLC     1979.0    5.0   6000.0    0.0
# 4  WALKER & WEST FAMILY PROPERTIES LLC     1985.0    1.0  10390.0    0.0
#
#    percentbasement   bldgvalue  realid  additionyr  effectiveyr
# 0              0.0  13114880.0   37845         0.0       1999.0
# 1             50.0    146396.0   37847         0.0       1965.0
# 2              0.0     95484.0   37866         0.0       1976.0
# 3              0.0    454607.0   37869         0.0       1979.0
# 4              0.0    454607.0   37869         0.0       1985.0

# %%
from sklearn.preprocessing import LabelEncoder
model=LabelEncoder()
df.owner=model.fit_transform(df.owner)
df.head()
# Out:
#     owner  yearbuilt  units     sqft  rooms  percentbasement   bldgvalue  \
# 0   52828     1999.0    6.0   7280.0    0.0              0.0  13114880.0
# 1   27407     1960.0    2.0   2982.0    0.0             50.0    146396.0
# 2   73863     1961.0    0.0   3224.0    0.0              0.0     95484.0
# 3  154502     1979.0    5.0   6000.0    0.0              0.0    454607.0
# 4  154502     1985.0    1.0  10390.0    0.0              0.0    454607.0
#
#    realid  additionyr  effectiveyr
# 0   37845         0.0       1999.0
# 1   37847         0.0       1965.0
# 2   37866         0.0       1976.0
# 3   37869         0.0       1979.0
# 4   37869         0.0       1985.0

# %%
median=df.yearbuilt.median()

# %%
df.yearbuilt.fillna(median)
df.yearbuilt=df.yearbuilt.fillna(median)

# %%
median=df.units.median()

# %%
df.units.fillna(median)
df.units=df.units.fillna(median)

# %%
median=df.sqft.median()
df.sqft.fillna(median)
df.sqft=df.sqft.fillna(median)

# %%
median=df.rooms.median()
df.rooms.fillna(median)
df.rooms=df.rooms.fillna(median)

# %%
median=df.rooms.median()
df.rooms.fillna(median)
df.rooms=df.rooms.fillna(median)

# %%
median=df.rooms.median()
df.rooms.fillna(median)
df.rooms=df.rooms.fillna(median)

# %%
median=df.percentbasement.median()
df.percentbasement.fillna(median)
df.percentbasement=df.percentbasement.fillna(median)

# %%
median=df.bldgvalue.median()
df.bldgvalue.fillna(median)
df.bldgvalue=df.bldgvalue.fillna(median)

# %%
median=df.realid.median()
df.realid.fillna(median)
df.realid=df.realid.fillna(median)

# %%
median=df.additionyr.median()
df.additionyr.fillna(median)
df.additionyr=df.additionyr.fillna(median)

# %%
median=df.effectiveyr.median()
df.effectiveyr.fillna(median)
df.effectiveyr=df.effectiveyr.fillna(median)

# %%
x=df.drop("bldgvalue",axis=1)
y=df.bldgvalue

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /Users/nikhilchaudhary/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/nikhilchaudhary/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a556f0421074> in <module>
# ----> 1 model.predict(x_test)
#
# NameError: name 'model' is not defined
